# %% [markdown]
# # Black Box Model 2: LSTM in PyTorch

# %%
import pandas as pd
from tqdm.notebook import tqdm
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import TensorDataset, Dataset, DataLoader
import lightning as L

pd.options.display.max_columns = 500

from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

# %load_ext blackcellmagic
# Out:
# The blackcellmagic extension is already loaded. To reload it, use:
#   %reload_ext blackcellmagic

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv("../00 Data Retrieval and Cleaning/0_df_final_imputed.csv")

# unselect the wrong direction target variable
df = df.drop(columns=["auction_price_ch_de", "allocatedCapacity_ch_de", "ATC_ch_de"])

# drop variables that are not needed
df = df.drop(columns=["ATC_de_ch", "allocatedCapacity_de_ch"])

# %%
df.head(3)
# Out:
#                    date  auction_price_de_ch  dst  day_ahead_price_at  \
# 0  2018-12-31T23:00:00Z                19.51    1               33.48
# 1  2019-01-01T00:00:00Z                21.96    1               39.76
# 2  2019-01-01T01:00:00Z                27.12    1               39.78
#
#    day_ahead_price_ch  day_ahead_price_de  day_ahead_price_fr  actual_load_at  \
# 0               50.26               28.32               51.00         6075.00
# 1               48.74               10.07               46.27         5852.75
# 2               47.24               -4.08               39.78         5619.25
#
#    actual_load_de  biomass_actual_aggregated_at  \
# 0         43713.5                         304.0
# 1         42091.0                         304.0
# 2         40537.0                         304.0
#
#    fossil_gas_actual_aggregated_at  fossil_hard_coal_actual_aggregated_at  \
# 0                          1282.75                                 155.75
# 1                           945.75                                 155.00
# 2                           618.75                                 155.50
#
#    hydro_pumped_storage_actual_aggregated_at  \
# 0                                        0.0
# 1                                        0.0
# 2                                        0.0
#
#    hydro_pumped_storage_actual_consumption_at  \
# 0                                     1620.50
# 1                                     1602.50
# 2                                     1440.25
#
#    hydro_run-of-river_and_poundage_actual_aggregated_at  \
# 0                                            2680.00
# 1                                            2703.50
# 2                                            2734.75
#
#    hydro_water_reservoir_actual_aggregated_at  solar_actual_aggregated_at  \
# 0                                      123.50                           0
# 1                                      161.50                           0
# 2                                       78.75                           0
#
#    wind_onshore_actual_aggregated_at  biomass_actual_aggregated_de  \
# 0                              248.0                       4831.25
# 1                              189.0                       4824.50
# 2                              142.0                       4782.25
#
#    fossil_brown_coal_lignite_actual_aggregated_de  \
# 0                                          6335.0
# 1                                          5379.5
# 2                                          5341.0
#
#    fossil_gas_actual_aggregated_de  fossil_hard_coal_actual_aggregated_de  \
# 0                          3281.75                                2811.75
# 1                          2975.25                                2404.25
# 2                          2728.00                                2228.50
#
#    fossil_oil_actual_aggregated_de  geothermal_actual_aggregated_de  \
# 0                           482.25                             19.0
# 1                           481.00                             19.0
# 2                           483.75                             19.0
#
#    hydro_pumped_storage_actual_aggregated_de  \
# 0                                     271.75
# 1                                      21.50
# 2                                     150.75
#
#    hydro_pumped_storage_actual_consumption_de  \
# 0                                      1375.0
# 1                                      1533.5
# 2                                      2598.5
#
#    hydro_run-of-river_and_poundage_actual_aggregated_de  \
# 0                                             1484.5
# 1                                             1493.5
# 2                                             1428.5
#
#    hydro_water_reservoir_actual_aggregated_de  other_actual_aggregated_de  \
# 0                                       86.75                      475.00
# 1                                       74.50                      435.75
# 2                                       97.25                      371.75
#
#    other_renewable_actual_aggregated_de  solar_actual_aggregated_de  \
# 0                                 107.0                         0.0
# 1                                 107.0                         0.0
# 2                                 107.0                         0.0
#
#    waste_actual_aggregated_de  wind_offshore_actual_aggregated_de  \
# 0                      778.25                             3134.00
# 1                      776.00                             2868.25
# 2                      780.25                             2460.25
#
#    wind_onshore_actual_aggregated_de  \
# 0                           20401.50
# 1                           22384.00
# 2                           23238.25
#
#    hydro_pumped_storage_actual_aggregated_fr  \
# 0                                          0
# 1                                          0
# 2                                          0
#
#    hydro_pumped_storage_actual_consumption_fr  actual_load_ch  actual_load_fr  \
# 0                                        1377            7037           62176
# 1                                        1536            7096           60301
# 2                                        2372            7244           58540
#
#    actual_load_it  solar_forecast_de  wind_onshore_forecast_fr  \
# 0           23644                0.0                      1698
# 1           22850                0.0                      1680
# 2           21600                0.0                      1675
#
#    hydro_pumped_storage_ch  hydro_run-of-river_and_poundage_ch  \
# 0                       81                                 123
# 1                       76                                 124
# 2                       31                                 126
#
#    hydro_water_reservoir_ch  nuclear_ch  solar_ch  wind_onshore_ch  \
# 0                       481        3243         0                1
# 1                       393        3243         0                0
# 2                       345        3245         0                0
#
#    nuclear_actual_aggregated_de  biomass_actual_aggregated_fr  \
# 0                       9001.50                           351
# 1                       8535.25                           352
# 2                       7954.00                           352
#
#    fossil_gas_actual_aggregated_fr  fossil_hard_coal_actual_aggregated_fr  \
# 0                             2722                                      0
# 1                             2526                                      0
# 2                             2425                                      0
#
#    fossil_oil_actual_aggregated_fr  \
# 0                              207
# 1                              215
# 2                              214
#
#    hydro_run-of-river_and_poundage_actual_aggregated_fr  \
# 0                                               3552
# 1                                               3344
# 2                                               3202
#
#    hydro_water_reservoir_actual_aggregated_fr  nuclear_actual_aggregated_fr  \
# 0                                        1054                         55627
# 1                                         740                         55113
# 2                                         463                         54780
#
#    solar_actual_aggregated_fr  waste_actual_aggregated_fr  \
# 0                           0                         253
# 1                           0                         252
# 2                           0                         253
#
#    wind_onshore_actual_aggregated_fr  biomass_actual_aggregated_it  \
# 0                               1622                           495
# 1                               1637                           501
# 2                               1567                           499
#
#    fossil_coal-derived_gas_actual_aggregated_it  \
# 0                                           776
# 1                                           775
# 2                                           773
#
#    fossil_gas_actual_aggregated_it  fossil_hard_coal_actual_aggregated_it  \
# 0                             8053                                   1938
# 1                             7614                                   2090
# 2                             7090                                   2177
#
#    fossil_oil_actual_aggregated_it  geothermal_actual_aggregated_it  \
# 0                                8                              674
# 1                                8                              673
# 2                                8                              673
#
#    hydro_pumped_storage_actual_aggregated_it  \
# 0                                          1
# 1                                          0
# 2                                          0
#
#    hydro_pumped_storage_actual_consumption_it  \
# 0                                          29
# 1                                          72
# 2                                         138
#
#    hydro_run-of-river_and_poundage_actual_aggregated_it  \
# 0                                               1891
# 1                                               1708
# 2                                               1613
#
#    hydro_water_reservoir_actual_aggregated_it  other_actual_aggregated_it  \
# 0                                         289                        3070
# 1                                         145                        3092
# 2                                         164                        2859
#
#    solar_actual_aggregated_it  waste_actual_aggregated_it  \
# 0                           0                          37
# 1                           0                          41
# 2                           0                          36
#
#    wind_onshore_actual_aggregated_it  hydro_reservoir_storage_at  \
# 0                               5076                     1412194
# 1                               5088                     1412194
# 2                               5086                     1412194
#
#    hydro_reservoir_storage_ch  hydro_reservoir_storage_fr  \
# 0                     4656491                     2186488
# 1                     4656491                     2186488
# 2                     4656491                     2186488
#
#    hydro_reservoir_storage_it  crossborder_actual_flow_at_ch  \
# 0                     3036299                            763
# 1                     3036299                            497
# 2                     3036299                            427
#
#    crossborder_actual_flow_ch_at  crossborder_actual_flow_ch_de_lu  \
# 0                              0                               595
# 1                              0                               502
# 2                              0                               512
#
#    crossborder_actual_flow_ch_fr  crossborder_actual_flow_ch_it  \
# 0                            553                           1468
# 1                            233                           1162
# 2                            280                            931
#
#    crossborder_actual_flow_de_lu_ch  crossborder_actual_flow_fr_ch  \
# 0                              3652                              0
# 1                              3536                              0
# 2                              3677                              0
#
#    crossborder_actual_flow_it_ch  capacity_forecast_at_ch  \
# 0                              0                     1200
# 1                              0                     1200
# 2                              0                     1200
#
#    capacity_forecast_ch_at  capacity_forecast_ch_de_lu  \
# 0                      700                        4000
# 1                      700                        4000
# 2                      700                        4000
#
#    capacity_forecast_ch_fr  capacity_forecast_ch_it  \
# 0                     1200                     2513
# 1                     1200                     2513
# 2                     1200                     2513
#
#    capacity_forecast_de_lu_ch  capacity_forecast_FR_CH  \
# 0                         800                     3000
# 1                         800                     3000
# 2                         800                     3000
#
#    capacity_forecast_it_ch  actual_load_ch_missing_dummy  \
# 0                     1910                             0
# 1                     1910                             0
# 2                     1910                             0
#
#    actual_load_fr_missing_dummy  actual_load_it_missing_dummy  \
# 0                             0                             0
# 1                             0                             0
# 2                             0                             0
#
#    solar_forecast_de_missing_dummy  wind_onshore_forecast_fr_missing_dummy  \
# 0                                0                                       0
# 1                                0                                       0
# 2                                0                                       0
#
#    hydro_pumped_storage_ch_missing_dummy  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    hydro_run-of-river_and_poundage_ch_missing_dummy  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
#
#    hydro_water_reservoir_ch_missing_dummy  nuclear_ch_missing_dummy  \
# 0                                       0                         0
# 1                                       0                         0
# 2                                       0                         0
#
#    solar_ch_missing_dummy  wind_onshore_ch_missing_dummy  \
# 0                       0                              0
# 1                       0                              0
# 2                       0                              0
#
#    nuclear_actual_aggregated_de_missing_dummy  \
# 0                                           0
# 1                                           0
# 2                                           0
#
#    biomass_actual_aggregated_fr_missing_dummy  \
# 0                                           0
# 1                                           0
# 2                                           0
#
#    fossil_gas_actual_aggregated_fr_missing_dummy  \
# 0                                              0
# 1                                              0
# 2                                              0
#
#    fossil_hard_coal_actual_aggregated_fr_missing_dummy  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
#
#    fossil_oil_actual_aggregated_fr_missing_dummy  \
# 0                                              0
# 1                                              0
# 2                                              0
#
#    hydro_run-of-river_and_poundage_actual_aggregated_fr_missing_dummy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    hydro_water_reservoir_actual_aggregated_fr_missing_dummy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    nuclear_actual_aggregated_fr_missing_dummy  \
# 0                                           0
# 1                                           0
# 2                                           0
#
#    solar_actual_aggregated_fr_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    waste_actual_aggregated_fr_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    wind_onshore_actual_aggregated_fr_missing_dummy  \
# 0                                                0
# 1                                                0
# 2                                                0
#
#    biomass_actual_aggregated_it_missing_dummy  \
# 0                                           0
# 1                                           0
# 2                                           0
#
#    fossil_coal-derived_gas_actual_aggregated_it_missing_dummy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    fossil_gas_actual_aggregated_it_missing_dummy  \
# 0                                              0
# 1                                              0
# 2                                              0
#
#    fossil_hard_coal_actual_aggregated_it_missing_dummy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    fossil_oil_actual_aggregated_it_missing_dummy  \
# 0                                              0
# 1                                              0
# 2                                              0
#
#    geothermal_actual_aggregated_it_missing_dummy  \
# 0                                              0
# 1                                              0
# 2                                              0
#
#    hydro_pumped_storage_actual_aggregated_it_missing_dummy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    hydro_pumped_storage_actual_consumption_it_missing_dummy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    hydro_run-of-river_and_poundage_actual_aggregated_it_missing_dummy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    hydro_water_reservoir_actual_aggregated_it_missing_dummy  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    other_actual_aggregated_it_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    solar_actual_aggregated_it_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    waste_actual_aggregated_it_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    wind_onshore_actual_aggregated_it_missing_dummy  \
# 0                                                0
# 1                                                0
# 2                                                0
#
#    hydro_reservoir_storage_at_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    hydro_reservoir_storage_ch_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    hydro_reservoir_storage_fr_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    hydro_reservoir_storage_it_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    crossborder_actual_flow_at_ch_missing_dummy  \
# 0                                            0
# 1                                            0
# 2                                            0
#
#    crossborder_actual_flow_ch_at_missing_dummy  \
# 0                                            0
# 1                                            0
# 2                                            0
#
#    crossborder_actual_flow_ch_de_lu_missing_dummy  \
# 0                                               0
# 1                                               0
# 2                                               0
#
#    crossborder_actual_flow_ch_fr_missing_dummy  \
# 0                                            0
# 1                                            0
# 2                                            0
#
#    crossborder_actual_flow_ch_it_missing_dummy  \
# 0                                            0
# 1                                            0
# 2                                            0
#
#    crossborder_actual_flow_de_lu_ch_missing_dummy  \
# 0                                               0
# 1                                               0
# 2                                               0
#
#    crossborder_actual_flow_fr_ch_missing_dummy  \
# 0                                            0
# 1                                            0
# 2                                            0
#
#    crossborder_actual_flow_it_ch_missing_dummy  \
# 0                                            0
# 1                                            0
# 2                                            0
#
#    capacity_forecast_at_ch_missing_dummy  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    capacity_forecast_ch_at_missing_dummy  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    capacity_forecast_ch_de_lu_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    capacity_forecast_ch_fr_missing_dummy  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    capacity_forecast_ch_it_missing_dummy  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    capacity_forecast_de_lu_ch_missing_dummy  \
# 0                                         0
# 1                                         0
# 2                                         0
#
#    capacity_forecast_FR_CH_missing_dummy  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    capacity_forecast_it_ch_missing_dummy
# 0                                      0
# 1                                      0
# 2                                      0

# %%
df.shape
# Out:
# (44510, 148)

# %%
X = df.drop(columns=["date", "auction_price_de_ch"])
y = df["auction_price_de_ch"]

train_size = int(0.6 * X.shape[0])
val_size = int(0.2 * X.shape[0])
test_size = X.shape[0] - train_size - val_size

sc = StandardScaler()

X_train = X.iloc[:train_size, :]
X_val = X.iloc[train_size:train_size + val_size, :]
X_test = X.iloc[train_size + val_size:, :]

y_train = y.iloc[:train_size].to_numpy()
y_val = y.iloc[train_size:train_size + val_size].to_numpy()
y_test = y.iloc[train_size + val_size:].to_numpy()

X_train = sc.fit_transform(X_train)
X_val = sc.transform(X_val)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Model

# %%
class LightningLSTM(L.LightningModule):
    def __init__(self, input_size, hidden_size, num_layers, output_size, lr=0.01,
                 noise_std=0.01):
        super().__init__()

        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.noise_std = noise_std
        self.lr = lr

        # Define LSTM layer
        self.lstm = nn.LSTM(
            input_size=input_size,  # number of features in input data
            hidden_size=self.hidden_size,  # number of output values
            num_layers=self.num_layers,
            batch_first=True,
        )
        self.add_noise_to_weights(self.lstm, self.noise_std)

        # Define fully connected layer
        self.fc = nn.Linear(self.hidden_size, output_size)

    def add_noise_to_weights(self, layer, std):
        for param in layer.parameters():
            if param.requires_grad:
                param.data.add_(torch.randn(param.size()) * std)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        
        return out
    
    def configure_optimizers(self):
        return Adam(self.parameters(), self.lr)
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        y_pred = self(x)

        # Calculate evaluation metric
        loss = nn.functional.l1_loss(y_pred, y)
        eval_metric = mean_absolute_error(y_pred.detach().numpy(), y.detach().numpy())

        # Log the evaluation metric to the training progress bar
        self.log("train/train_eval_metric", eval_metric, on_step=True, on_epoch=False)

        return {"loss": loss, "eval_metric": eval_metric}
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        y_pred = self(x)
        eval_metric = mean_absolute_error(y_pred.detach().numpy(), y.detach().numpy())
        
        # Log the evaluation metric to the validation progress bar
        self.log("val/val_eval_metric", eval_metric, on_step=True, on_epoch=False)
        
        return {"val_eval_metric": eval_metric}
    
    def test_step(self, batch, batch_idx):
        x, y = batch
        y_pred = self(x)
        eval_metric = mean_absolute_error(y_pred.detach().numpy(), y.detach().numpy())
        
        # Log the evaluation metric to the validation progress bar
        self.log("val/test_eval_metric", eval_metric, on_step=True, on_epoch=False)
        
        return {"test_eval_metric": eval_metric}

# %%
# Set the default data type for torch tensors to float32
torch.set_default_dtype(torch.float32)

# %%
# Create Sequences and Targets
def create_sequences(X, y, sequence_length, target_length):
    """Create sequences and targets from data.

    Args:
        X (np.ndarray): Input data.
        y (pd.Series): Target data.
        sequence_length (int): Length of the sequence.
        target_length (int): Length of the target/forecasting horizon in periods.

    Returns:
        _type_: _description_
    """
    sequences = []
    targets = []
    for i in tqdm(range(X.shape[0] - sequence_length - target_length + 1)):
        # seq = X[i:i + sequence_length, :]
        # target = y[i + sequence_length:i + sequence_length + target_length]
        seq = X[i:(i + sequence_length + target_length), :]
        target = y[(i + sequence_length):(i + sequence_length + target_length)]
        sequences.append(seq)
        targets.append(target)
    sequences = np.array(sequences)
    targets = np.array(targets)
    
    return torch.tensor(sequences, dtype = torch.float32), torch.tensor(targets, dtype = torch.float32)

# %%
X_train_seq, y_train_seq = create_sequences(X_train, y_train, 48, 24)
X_val_seq, y_val_seq = create_sequences(X_val, y_val, 48, 24)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, 48, 24)
# Out:
#   0%|          | 0/26635 [00:00<?, ?it/s]
#   0%|          | 0/8831 [00:00<?, ?it/s]
#   0%|          | 0/8831 [00:00<?, ?it/s]

# %%
class CustomDataset(Dataset):
    def __init__(self, inputs, targets):
        """
        Args:
            inputs (list): List of input sequences (PyTorch tensors or NumPy arrays).
            targets (list): List of target sequences (PyTorch tensors or NumPy arrays).
        """
        self.inputs = inputs
        self.targets = targets

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        input_sequence = self.inputs[idx]
        target_sequence = self.targets[idx]

        return input_sequence, target_sequence

# %%
X.shape
# Out:
# (44510, 146)

# %%
train_set = CustomDataset(X_train_seq, y_train_seq)
val_set = CustomDataset(X_val_seq, y_val_seq)
test_set = CustomDataset(X_test_seq, y_test_seq)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)

# %%
# Create a Lightning model with the sampled hyperparameters
model = LightningLSTM(
    input_size=X.shape[1],
    hidden_size=128,
    num_layers=2,
    output_size=24,
    lr=0.01,
    noise_std=0.01,
)

model
# Out:
# LightningLSTM(
#   (lstm): LSTM(146, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=24, bias=True)
# )

# %%
# Create a PyTorch Lightning Trainer
trainer = L.Trainer(max_epochs=10)  # Adjust the number of epochs as needed

# Train the model
trainer.fit(model, train_loader, val_loader)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\connectors\logger_connector\logger_connector.py:75: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# Missing logger folder: c:\Users\mathi\OneDrive\Universitaet\2nd Semester\2_Statistics Lab\RWE-ETH-Power-Trading\01 Task 1 - Spot Price\lightning_logs
#
#   | Name | Type   | Params
# --------------------------------
# 0 | lstm | LSTM   | 273 K
# 1 | fc   | Linear | 3.1 K
# --------------------------------
# 276 K     Trainable params
# 0         Non-trainable params
# 276 K     Total params
# 1.106     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\call.py:54: Detected KeyboardInterrupt, attempting graceful shutdown...

# %%
# Return the metric you want to optimize (e.g., validation loss)
trainer.logged_metrics.get("val/val_eval_metric").item()
# Out:
# 2.857717752456665

# %% [markdown]
# ### Making Predictions on the Test Period

# %%
trainer.predict(model=model, dataloaders=train_loader)
# Out:
# c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:492: Your `predict_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
# c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Predicting: |          | 0/? [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 trainer.predict(model=model, dataloaders=train_loader)
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\trainer.py:864, in Trainer.predict(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     862 self.state.status = TrainerStatus.RUNNING
#     863 self.predicting = True
# --> 864 return call._call_and_handle_interrupt(
#     865     self, self._predict_impl, model, dataloaders, datamodule, return_predictions, ckpt_path
#     866 )
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\trainer.py:903, in Trainer._predict_impl(self, model, dataloaders, datamodule, return_predictions, ckpt_path)
#     899 assert self.state.fn is not None
#     900 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     901     self.state.fn, ckpt_path, model_provided=model_provided, model_connected=self.lightning_module is not None
#     902 )
# --> 903 results = self._run(model, ckpt_path=ckpt_path)
#     905 assert self.state.stopped
#     906 self.predicting = False
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\trainer.py:987, in Trainer._run(self, model, ckpt_path)
#     982 self._signal_connector.register_signal_handlers()
#     984 # ----------------------------
#     985 # RUN THE TRAINER
#     986 # ----------------------------
# --> 987 results = self._run_stage()
#     989 # ----------------------------
#     990 # POST-Training CLEAN UP
#     991 # ----------------------------
#     992 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\trainer.py:1028, in Trainer._run_stage(self)
#    1026     return self._evaluation_loop.run()
#    1027 if self.predicting:
# -> 1028     return self.predict_loop.run()
#    1029 if self.training:
#    1030     with isolate_rng():
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\loops\utilities.py:182, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     180     context_manager = torch.no_grad
#     181 with context_manager():
# --> 182     return loop_run(self, *args, **kwargs)
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\loops\prediction_loop.py:124, in _PredictionLoop.run(self)
#     122     self.batch_progress.is_last_batch = data_fetcher.done
#     123     # run step hooks
# --> 124     self._predict_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     125 except StopIteration:
#     126     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#     127     break
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\loops\prediction_loop.py:253, in _PredictionLoop._predict_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     247 # configure step_kwargs
#     248 step_args = (
#     249     self._build_step_args_from_hook_kwargs(hook_kwargs, "predict_step")
#     250     if not using_dataloader_iter
#     251     else (dataloader_iter,)
#     252 )
# --> 253 predictions = call._call_strategy_hook(trainer, "predict_step", *step_args)
#     254 if predictions is None:
#     255     self._warning_cache.warn("predict returned None if it was on purpose, ignore this warning...")
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\trainer\call.py:309, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     306     return None
#     308 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 309     output = fn(*args, **kwargs)
#     311 # restore current_fx when nested context
#     312 pl_module._current_fx_name = prev_fx_name
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\strategies\strategy.py:438, in Strategy.predict_step(self, *args, **kwargs)
#     436 if self.model != self.lightning_module:
#     437     return self._forward_redirection(self.model, self.lightning_module, "predict_step", *args, **kwargs)
# --> 438 return self.lightning_module.predict_step(*args, **kwargs)
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\lightning\pytorch\core\module.py:921, in LightningModule.predict_step(self, *args, **kwargs)
#     919 # For backwards compatibility
#     920 batch = kwargs.get("batch", args[0])
# --> 921 return self(batch)
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\mathi\miniconda3\envs\statslab\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[8], line 29, in LightningLSTM.forward(self, x)
#      28 def forward(self, x):
# ---> 29     h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
#      30     c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
#      32     out, _ = self.lstm(x, (h0, c0))
#
# AttributeError: 'list' object has no attribute 'size'
